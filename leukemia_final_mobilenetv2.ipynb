# %%
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from matplotlib import pyplot as plt
import math, os, re, warnings, random
from sklearn.utils import class_weight
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras import optimizers, applications, Sequential, losses, metrics
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler

# %%
def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = "1"


seed = 0
seed_everything(seed)
warnings.filterwarnings('ignore')

# %%
strategy = tf.distribute.get_strategy()
AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print('# REPLICAS: {}'.format(REPLICAS))
# Out:
# # REPLICAS: 1

# %%
BATCH_SIZE = 32 * REPLICAS
LEARNING_RATE = 3e-5 * REPLICAS
EPOCHS = 35
HEIGHT = 300
WIDTH = 300
CHANNELS = 3
ES_PATIENCE = 10
AUG_BATCH=BATCH_SIZE
IMAGE_SIZE=[HEIGHT,WIDTH]

# %%
# GCS_PATH = KaggleDatasets().get_gcs_path('leukemia-classification')
GCS_PATH = '../input/leukemia-classification/'

# %%
train_dataset_0_all = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_0/all/*.bmp')
train_dataset_0_hem = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_0/hem/*.bmp')
train_dataset_1_all = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_1/all/*.bmp')
train_dataset_1_hem = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_1/hem/*.bmp')
train_dataset_2_all = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_2/all/*.bmp')
train_dataset_2_hem = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_2/hem/*.bmp')

# %%
len(train_dataset_0_all)
# Out:
# 2397

# %%
# Include Validation data as well :-
test_data=pd.read_csv(GCS_PATH + '/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data_labels.csv')

at = test_data[test_data['labels'] == 1]
ht = test_data[test_data['labels'] == 0]

test_PATH = GCS_PATH + '/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/'
ATL = [test_PATH +  i for i in list(at.new_names)]
HTL = [test_PATH +  i for i in list(ht.new_names)]

# %%
# Merging happens here:-
A=[]
H=[]
A.extend(train_dataset_0_all)
A.extend(train_dataset_1_all)
A.extend(train_dataset_2_all)

H.extend(train_dataset_0_hem)
H.extend(train_dataset_1_hem)
H.extend(train_dataset_2_hem)

print(len(A))
print(len(H))

# Create labels :-
Label_A = [1]*len(A)
Label_H = [0]*len(H)

# Converting to pandas dataframe for easier access:-
A.extend(H)
Label_A.extend(Label_H)
df = pd.DataFrame({'path':A, 'label':Label_A})
df = df.sample(frac=1).reset_index(drop=True)

FILENAMES = df['path']
LABELS = df['label']

print('Final Merged Data:-')
df
# Out:
# 7272
# 3389
# Final Merged Data:-
#                                                     path  label
# 0      ../input/leukemia-classification//C-NMC_Leukem...      1
# 1      ../input/leukemia-classification//C-NMC_Leukem...      1
# 2      ../input/leukemia-classification//C-NMC_Leukem...      0
# 3      ../input/leukemia-classification//C-NMC_Leukem...      0
# 4      ../input/leukemia-classification//C-NMC_Leukem...      1
# ...                                                  ...    ...
# 10656  ../input/leukemia-classification//C-NMC_Leukem...      0
# 10657  ../input/leukemia-classification//C-NMC_Leukem...      1
# 10658  ../input/leukemia-classification//C-NMC_Leukem...      1
# 10659  ../input/leukemia-classification//C-NMC_Leukem...      0
# 10660  ../input/leukemia-classification//C-NMC_Leukem...      1
#
# [10661 rows x 2 columns]

# %%
cw = class_weight.compute_class_weight('balanced',
                                        np.unique(LABELS),
                                        LABELS)
cw = {0:cw[0], 1:cw[1]}

# %%
cw
# Out:
# {0: 1.5728828562997934, 1: 0.7330170517051705}

# %%
# Define Augmentation function:-
def data_augment(image, label):

    p_spatial = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_shear = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_crop = tf.random.uniform([], 0, 1.0, dtype=tf.float32)

    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_flip_left_right(image)

    if p_spatial > .75:
        image = tf.image.transpose(image)

    if p_pixel >= .2:
        if p_pixel >= .8:
            image = tf.image.random_saturation(image, lower=.7, upper=1.3)
        elif p_pixel >= .6:
            image = tf.image.random_contrast(image, lower=.8, upper=1.2)
        elif p_pixel >= .4:
            image = tf.image.random_brightness(image, max_delta=.1)
        else:
            image = tf.image.adjust_gamma(image, gamma=.6)

    if p_crop > .7:
        if p_crop > .9:
            image = tf.image.central_crop(image, central_fraction=.6)
        elif p_crop > .8:
            image = tf.image.central_crop(image, central_fraction=.7)
        else:
            image = tf.image.central_crop(image, central_fraction=.8)
    elif p_crop > .4:
        crop_size = tf.random.uniform([], int(HEIGHT*.6), HEIGHT, dtype=tf.int32)
        image = tf.image.random_crop(image, size=[crop_size, crop_size, CHANNELS])

    image = tf.image.resize(image, size=[HEIGHT, WIDTH])
    image = tf.reshape(image, [HEIGHT, WIDTH, 3])

    return image, label

# %%
def parse_data(filename,label):
    image = tf.io.read_file(filename)
    image = tf.image.decode_bmp(image)
    image = tf.image.convert_image_dtype(image, tf.float32) /  0.45
    image = tf.image.resize(image, IMAGE_SIZE)
    return image, tf.one_hot(label,2)

def load_dataset(filenames, labels ,ordered=False):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False

    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
    dataset = dataset.with_options(ignore_order)
    dataset = dataset.map(parse_data, num_parallel_calls=AUTO)
    return dataset

def get_dataset(FILENAMES,LABELS, ordered=False, repeated=False, augment=False):
    dataset = load_dataset(FILENAMES, LABELS, ordered=ordered)
    if augment:
        dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO)
    return dataset

# %%
import math
np.set_printoptions(threshold=15, linewidth=80)
CLASSES = [0,1]

def batch_to_numpy_images_and_labels(data):
    images, labels = data
    numpy_images = images.numpy()
    numpy_labels = labels.numpy()
    labels = [str(i) for i in  numpy_labels]

    return numpy_images, labels

def title_from_label_and_target(label, correct_label):
    if correct_label is None:
        return CLASSES[label], True
    correct = (label == correct_label)
    return "{} [{}{}{}]".format(CLASSES[label], 'OK' if correct else 'NO', u"\u2192" if not correct else '',
                                CLASSES[correct_label] if not correct else ''), correct

def display_one_flower(image, title, subplot, red=False, titlesize=16):
    plt.subplot(*subplot)
    plt.axis('off')
    plt.imshow(image)
    if len(title) > 0:
        plt.title(title, fontsize=int(titlesize) if not red else int(titlesize/1.2), color='red' if red else 'black', fontdict={'verticalalignment':'center'}, pad=int(titlesize/1.5))
    return (subplot[0], subplot[1], subplot[2]+1)

def display_batch_of_images(databatch, predictions=None):
    """This will work with:
    display_batch_of_images(images)
    display_batch_of_images(images, predictions)
    display_batch_of_images((images, labels))
    display_batch_of_images((images, labels), predictions)
    """
    # data
    images, labels = batch_to_numpy_images_and_labels(databatch)
    if labels is None:
        labels = [None for _ in enumerate(images)]

    # auto-squaring: this will drop data that does not fit into square or square-ish rectangle
    rows = int(math.sqrt(len(images)))
    cols = len(images)//rows

    # size and spacing
    FIGSIZE = 13.0
    SPACING = 0.1
    subplot=(rows,cols,1)
    if rows < cols:
        plt.figure(figsize=(FIGSIZE,FIGSIZE/cols*rows))
    else:
        plt.figure(figsize=(FIGSIZE/rows*cols,FIGSIZE))

    # display
    for i, (image, label) in enumerate(zip(images[:rows*cols], labels[:rows*cols])):
        title = label
        correct = True
        if predictions is not None:
            title, correct = title_from_label_and_target(predictions[i], label)
        dynamic_titlesize = FIGSIZE*SPACING/max(rows,cols)*40+3 # magic formula tested to work from 1x1 to 10x10 images
        # image = cv2.imdecode(image,cv2.IMREA)
        subplot = display_one_flower(image, title, subplot, not correct, titlesize=dynamic_titlesize)

    #layout
    plt.tight_layout()
    if label is None and predictions is None:
        plt.subplots_adjust(wspace=0, hspace=0)
    else:
        plt.subplots_adjust(wspace=SPACING, hspace=SPACING)


# Model evaluation
def plot_metrics(history):
    metric_list = [m for m in list(history.keys()) if m is not 'lr']
    size = len(metric_list)//2
    fig, axes = plt.subplots(size, 1, sharex='col', figsize=(20, size * 4))
    if size > 1:
        axes = axes.flatten()
    else:
        axes = [axes]

    for index in range(len(metric_list)//2):
        metric_name = metric_list[index]
        val_metric_name = metric_list[index+size]
        axes[index].plot(history[metric_name], label='Train %s' % metric_name)
        axes[index].plot(history[val_metric_name], label='Validation %s' % metric_name)
        axes[index].legend(loc='best', fontsize=16)
        axes[index].set_title(metric_name)
        if 'loss' in metric_name:
            axes[index].axvline(np.argmin(history[metric_name]), linestyle='dashed')
            axes[index].axvline(np.argmin(history[val_metric_name]), linestyle='dashed', color='orange')
        else:
            axes[index].axvline(np.argmax(history[metric_name]), linestyle='dashed')
            axes[index].axvline(np.argmax(history[val_metric_name]), linestyle='dashed', color='orange')

    plt.xlabel('Epochs', fontsize=16)
    sns.despine()
    plt.show()

# %%
train_dataset = get_dataset(FILENAMES[:60],LABELS[:60], ordered=True,augment=True)
train_iter = iter(train_dataset.unbatch().batch(20))

display_batch_of_images(next(train_iter))
display_batch_of_images(next(train_iter))

# %%
# Cosine Annealing:-
LR_START = 1e-8
LR_MIN = 1e-8
LR_MAX = LEARNING_RATE
LR_RAMPUP_EPOCHS = 3
LR_SUSTAIN_EPOCHS = 0
N_CYCLES = .5


def lrfn(epoch):
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        progress = (epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) / (EPOCHS - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS)
        lr = LR_MAX * (0.5 * (1.0 + tf.math.cos(math.pi * N_CYCLES * 2.0 * progress)))
        if LR_MIN is not None:
            lr = tf.math.maximum(LR_MIN, lr)

    return lr

rng = [i for i in range(EPOCHS)]
y = [lrfn(x) for x in rng]

sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(20, 6))
plt.plot(rng, y)

# print(f'{EPOCHS} total epochs and {NUM_TRAINING_IMAGES//BATCH_SIZE} steps per epoch')
print(f'Learning rate schedule: {y[0]:.3g} to {max(y):.3g} to {y[-1]:.3g}')
# Out:
# Learning rate schedule: 1e-08 to 3e-05 to 7.22e-08

# %%
import tensorflow_addons as tfa

# %%
# Model Architecture :-
def model_fn(input_shape, N_CLASSES):
    input_image = L.Input(shape=input_shape, name='input_image')
    base_model = tf.keras.applications.mobilenet_v2.MobileNetV2(input_tensor=input_image,
                                    include_top=False,
                                    weights='imagenet',
                                    pooling='avg')

    for layer in base_model.layers:
        if 'bn' in layer.name:
            layer.trainable = False
        else:
            layer.trainable = True

    model = tf.keras.Sequential([
        base_model,
        L.Dropout(.25),
        L.Dense(N_CLASSES, activation='sigmoid', name='output')
    ])

    optimizer = optimizers.Adam(lr=LEARNING_RATE)
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy',tfa.metrics.F1Score(num_classes=2, average='weighted')])

    return model

# %%
# Cross Validated training loop:-
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []
cv1 = cv2 = 0


for fold,(idxT, idxV) in enumerate(skf.split(FILENAMES,LABELS)):
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    STEPS_PER_EPOCH = len(idxT) // BATCH_SIZE


    K.clear_session()
    with strategy.scope():
        model = model_fn((None, None, CHANNELS), 2)

    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_f1_score', mode='max',
                    patience=ES_PATIENCE, restore_best_weights=True, verbose=1)

    ## TRAIN
    history = model.fit(x=get_dataset(FILENAMES[idxT],LABELS[idxT], ordered=False, repeated=True, augment=True),
                        validation_data=get_dataset(FILENAMES[idxV],LABELS[idxV] , ordered=True, repeated=False, augment=False),
                        steps_per_epoch=STEPS_PER_EPOCH,
                        callbacks=[es, LearningRateScheduler(lrfn ,verbose=0)],
                        epochs=EPOCHS,
                        verbose=1,
                        class_weight = cw).history

    model.save_weights(model_path)
    history_list.append(history)
    # Save last model weights


    ## RESULTS
    print(f"#### FOLD {fold+1} Accuracy = {np.max(history['accuracy']):.3f}")
    print(f"#### FOLD {fold+1} F1_score = {np.max(history['f1_score']):.3f}")
    cv1 += np.max(history['accuracy'])
    cv2 += np.max(history['f1_score'])


print(f'### Avg. Accuracy = {cv1/3.0} \n ### Avg. Weighted F1 = {cv2/3.0}')
# Out:
# FOLD: 1
# TRAIN: 7107 VALID: 3554
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Epoch 1/35
# 222/222 [==============================] - 141s 496ms/step - loss: 0.8022 - accuracy: 0.4741 - f1_score: 0.4895 - val_loss: 0.9097 - val_accuracy: 0.3292 - val_f1_score: 0.1838
# Epoch 2/35
# 222/222 [==============================] - 91s 409ms/step - loss: 0.6424 - accuracy: 0.6502 - f1_score: 0.6605 - val_loss: 1.2388 - val_accuracy: 0.3185 - val_f1_score: 0.1546
# Epoch 3/35
# 222/222 [==============================] - 78s 351ms/step - loss: 0.4737 - accuracy: 0.8043 - f1_score: 0.8070 - val_loss: 1.5654 - val_accuracy: 0.3180 - val_f1_score: 0.1539
# Epoch 4/35
# 222/222 [==============================] - 79s 354ms/step - loss: 0.3886 - accuracy: 0.8367 - f1_score: 0.8385 - val_loss: 1.9968 - val_accuracy: 0.3177 - val_f1_score: 0.1533
# Epoch 5/35
# 222/222 [==============================] - 78s 353ms/step - loss: 0.3531 - accuracy: 0.8557 - f1_score: 0.8569 - val_loss: 1.7857 - val_accuracy: 0.3306 - val_f1_score: 0.1811
# Epoch 6/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.3008 - accuracy: 0.8857 - f1_score: 0.8864 - val_loss: 1.1229 - val_accuracy: 0.4643 - val_f1_score: 0.4238
# Epoch 7/35
# 222/222 [==============================] - 77s 347ms/step - loss: 0.2656 - accuracy: 0.8932 - f1_score: 0.8943 - val_loss: 0.8892 - val_accuracy: 0.5926 - val_f1_score: 0.5942
# Epoch 8/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.2648 - accuracy: 0.8986 - f1_score: 0.8991 - val_loss: 0.6081 - val_accuracy: 0.7358 - val_f1_score: 0.7448
# Epoch 9/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.2174 - accuracy: 0.9169 - f1_score: 0.9174 - val_loss: 0.4260 - val_accuracy: 0.8205 - val_f1_score: 0.8228
# Epoch 10/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.2115 - accuracy: 0.9231 - f1_score: 0.9234 - val_loss: 0.4051 - val_accuracy: 0.8447 - val_f1_score: 0.8441
# Epoch 11/35
# 222/222 [==============================] - 78s 351ms/step - loss: 0.2199 - accuracy: 0.9211 - f1_score: 0.9214 - val_loss: 0.3697 - val_accuracy: 0.8613 - val_f1_score: 0.8574
# Epoch 12/35
# 222/222 [==============================] - 78s 349ms/step - loss: 0.2074 - accuracy: 0.9266 - f1_score: 0.9268 - val_loss: 0.3367 - val_accuracy: 0.8703 - val_f1_score: 0.8709
# Epoch 13/35
# 222/222 [==============================] - 78s 351ms/step - loss: 0.1893 - accuracy: 0.9231 - f1_score: 0.9236 - val_loss: 0.3415 - val_accuracy: 0.8582 - val_f1_score: 0.8606
# Epoch 14/35
# 222/222 [==============================] - 77s 349ms/step - loss: 0.1834 - accuracy: 0.9290 - f1_score: 0.9295 - val_loss: 0.3229 - val_accuracy: 0.8880 - val_f1_score: 0.8819
# Epoch 15/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.1704 - accuracy: 0.9357 - f1_score: 0.9362 - val_loss: 0.2192 - val_accuracy: 0.9212 - val_f1_score: 0.9200
# Epoch 16/35
# 222/222 [==============================] - 77s 349ms/step - loss: 0.1505 - accuracy: 0.9462 - f1_score: 0.9465 - val_loss: 0.2248 - val_accuracy: 0.9156 - val_f1_score: 0.9164
# Epoch 17/35
# 222/222 [==============================] - 77s 349ms/step - loss: 0.1676 - accuracy: 0.9362 - f1_score: 0.9367 - val_loss: 0.1650 - val_accuracy: 0.9409 - val_f1_score: 0.9400
# Epoch 18/35
# 222/222 [==============================] - 78s 351ms/step - loss: 0.1606 - accuracy: 0.9373 - f1_score: 0.9377 - val_loss: 0.1828 - val_accuracy: 0.9313 - val_f1_score: 0.9296
# Epoch 19/35
# 222/222 [==============================] - 77s 347ms/step - loss: 0.1554 - accuracy: 0.9421 - f1_score: 0.9424 - val_loss: 0.1628 - val_accuracy: 0.9412 - val_f1_score: 0.9402
# Epoch 20/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.1377 - accuracy: 0.9498 - f1_score: 0.9500 - val_loss: 0.1531 - val_accuracy: 0.9457 - val_f1_score: 0.9461
# Epoch 21/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.1496 - accuracy: 0.9431 - f1_score: 0.9434 - val_loss: 0.1274 - val_accuracy: 0.9527 - val_f1_score: 0.9525
# Epoch 22/35
# 222/222 [==============================] - 78s 351ms/step - loss: 0.1452 - accuracy: 0.9509 - f1_score: 0.9511 - val_loss: 0.1253 - val_accuracy: 0.9550 - val_f1_score: 0.9548
# Epoch 23/35
# 222/222 [==============================] - 77s 349ms/step - loss: 0.1221 - accuracy: 0.9589 - f1_score: 0.9590 - val_loss: 0.1370 - val_accuracy: 0.9513 - val_f1_score: 0.9516
# Epoch 24/35
# 222/222 [==============================] - 77s 349ms/step - loss: 0.1412 - accuracy: 0.9402 - f1_score: 0.9405 - val_loss: 0.1315 - val_accuracy: 0.9508 - val_f1_score: 0.9510
# Epoch 25/35
# 222/222 [==============================] - 78s 349ms/step - loss: 0.1304 - accuracy: 0.9495 - f1_score: 0.9498 - val_loss: 0.1617 - val_accuracy: 0.9350 - val_f1_score: 0.9359
# Epoch 26/35
# 222/222 [==============================] - 77s 348ms/step - loss: 0.1216 - accuracy: 0.9535 - f1_score: 0.9538 - val_loss: 0.2011 - val_accuracy: 0.9249 - val_f1_score: 0.9263
# Epoch 27/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.1098 - accuracy: 0.9583 - f1_score: 0.9584 - val_loss: 0.1677 - val_accuracy: 0.9370 - val_f1_score: 0.9379
# Epoch 28/35
# 222/222 [==============================] - 93s 418ms/step - loss: 0.1295 - accuracy: 0.9540 - f1_score: 0.9542 - val_loss: 0.1328 - val_accuracy: 0.9488 - val_f1_score: 0.9492
# Epoch 29/35
# 222/222 [==============================] - 79s 357ms/step - loss: 0.1176 - accuracy: 0.9545 - f1_score: 0.9548 - val_loss: 0.1302 - val_accuracy: 0.9499 - val_f1_score: 0.9502
# Epoch 30/35
# 222/222 [==============================] - 77s 349ms/step - loss: 0.1265 - accuracy: 0.9567 - f1_score: 0.9568 - val_loss: 0.1201 - val_accuracy: 0.9553 - val_f1_score: 0.9553
# Epoch 31/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.1130 - accuracy: 0.9577 - f1_score: 0.9580 - val_loss: 0.1155 - val_accuracy: 0.9561 - val_f1_score: 0.9561
# Epoch 32/35
# 222/222 [==============================] - 78s 353ms/step - loss: 0.1256 - accuracy: 0.9527 - f1_score: 0.9528 - val_loss: 0.1212 - val_accuracy: 0.9536 - val_f1_score: 0.9537
# Epoch 33/35
# 222/222 [==============================] - 79s 357ms/step - loss: 0.1154 - accuracy: 0.9588 - f1_score: 0.9588 - val_loss: 0.1195 - val_accuracy: 0.9547 - val_f1_score: 0.9548
# Epoch 34/35
# 222/222 [==============================] - 91s 409ms/step - loss: 0.1149 - accuracy: 0.9587 - f1_score: 0.9589 - val_loss: 0.1195 - val_accuracy: 0.9544 - val_f1_score: 0.9545
# Epoch 35/35
# 222/222 [==============================] - 79s 356ms/step - loss: 0.1174 - accuracy: 0.9555 - f1_score: 0.9557 - val_loss: 0.1196 - val_accuracy: 0.9544 - val_f1_score: 0.9545
# #### FOLD 1 Accuracy = 0.961
# #### FOLD 1 F1_score = 0.961
#
# FOLD: 2
# TRAIN: 7107 VALID: 3554
# Epoch 1/35
# 222/222 [==============================] - 92s 369ms/step - loss: 0.7852 - accuracy: 0.5635 - f1_score: 0.5545 - val_loss: 0.7047 - val_accuracy: 0.6801 - val_f1_score: 0.5522
# Epoch 2/35
# 222/222 [==============================] - 79s 358ms/step - loss: 0.6334 - accuracy: 0.6825 - f1_score: 0.6889 - val_loss: 0.7546 - val_accuracy: 0.6252 - val_f1_score: 0.6363
# Epoch 3/35
# 222/222 [==============================] - 78s 349ms/step - loss: 0.4914 - accuracy: 0.7854 - f1_score: 0.7883 - val_loss: 0.8864 - val_accuracy: 0.3551 - val_f1_score: 0.2331
# Epoch 4/35
# 222/222 [==============================] - 78s 350ms/step - loss: 0.3855 - accuracy: 0.8389 - f1_score: 0.8412 - val_loss: 0.8847 - val_accuracy: 0.4097 - val_f1_score: 0.3407
# Epoch 5/35
# 222/222 [==============================] - 77s 348ms/step - loss: 0.3394 - accuracy: 0.8566 - f1_score: 0.8575 - val_loss: 1.1205 - val_accuracy: 0.3590 - val_f1_score: 0.2425
# Epoch 6/35
# 222/222 [==============================] - 80s 361ms/step - loss: 0.2884 - accuracy: 0.8909 - f1_score: 0.8915 - val_loss: 0.9531 - val_accuracy: 0.4482 - val_f1_score: 0.4029
# Epoch 7/35
# 222/222 [==============================] - 79s 358ms/step - loss: 0.2568 - accuracy: 0.8990 - f1_score: 0.8998 - val_loss: 0.8020 - val_accuracy: 0.5360 - val_f1_score: 0.5296
# Epoch 8/35
# 222/222 [==============================] - 79s 354ms/step - loss: 0.2527 - accuracy: 0.9039 - f1_score: 0.9046 - val_loss: 0.5523 - val_accuracy: 0.7358 - val_f1_score: 0.7439
# Epoch 9/35
# 222/222 [==============================] - 80s 361ms/step - loss: 0.2268 - accuracy: 0.9126 - f1_score: 0.9133 - val_loss: 0.4766 - val_accuracy: 0.7963 - val_f1_score: 0.7951
# Epoch 10/35
# 222/222 [==============================] - 82s 371ms/step - loss: 0.2138 - accuracy: 0.9133 - f1_score: 0.9140 - val_loss: 0.4949 - val_accuracy: 0.8199 - val_f1_score: 0.8030
# Epoch 11/35
# 222/222 [==============================] - 93s 421ms/step - loss: 0.2074 - accuracy: 0.9262 - f1_score: 0.9267 - val_loss: 0.4613 - val_accuracy: 0.8360 - val_f1_score: 0.8218
# Epoch 12/35
# 222/222 [==============================] - 80s 359ms/step - loss: 0.1805 - accuracy: 0.9315 - f1_score: 0.9319 - val_loss: 0.4829 - val_accuracy: 0.8391 - val_f1_score: 0.8234
# Epoch 13/35
# 222/222 [==============================] - 81s 364ms/step - loss: 0.1882 - accuracy: 0.9249 - f1_score: 0.9255 - val_loss: 0.5072 - val_accuracy: 0.8315 - val_f1_score: 0.8121
# Epoch 14/35
# 222/222 [==============================] - 83s 372ms/step - loss: 0.1587 - accuracy: 0.9421 - f1_score: 0.9425 - val_loss: 0.3311 - val_accuracy: 0.8815 - val_f1_score: 0.8757
# Epoch 15/35
# 222/222 [==============================] - 86s 387ms/step - loss: 0.1659 - accuracy: 0.9347 - f1_score: 0.9352 - val_loss: 0.5402 - val_accuracy: 0.8289 - val_f1_score: 0.8083
# Epoch 16/35
# 222/222 [==============================] - 87s 392ms/step - loss: 0.1658 - accuracy: 0.9354 - f1_score: 0.9359 - val_loss: 0.3262 - val_accuracy: 0.8872 - val_f1_score: 0.8809
# Epoch 17/35
# 222/222 [==============================] - 78s 354ms/step - loss: 0.1538 - accuracy: 0.9380 - f1_score: 0.9384 - val_loss: 0.3744 - val_accuracy: 0.8835 - val_f1_score: 0.8762
# Epoch 18/35
# 222/222 [==============================] - 81s 364ms/step - loss: 0.1535 - accuracy: 0.9418 - f1_score: 0.9420 - val_loss: 0.2267 - val_accuracy: 0.9207 - val_f1_score: 0.9182
# Epoch 19/35
# 222/222 [==============================] - 84s 378ms/step - loss: 0.1521 - accuracy: 0.9403 - f1_score: 0.9407 - val_loss: 0.2788 - val_accuracy: 0.9055 - val_f1_score: 0.9011
# Epoch 20/35
# 222/222 [==============================] - 86s 389ms/step - loss: 0.1370 - accuracy: 0.9472 - f1_score: 0.9475 - val_loss: 0.1868 - val_accuracy: 0.9325 - val_f1_score: 0.9309
# Epoch 21/35
# 222/222 [==============================] - 87s 391ms/step - loss: 0.1360 - accuracy: 0.9510 - f1_score: 0.9513 - val_loss: 0.2209 - val_accuracy: 0.9192 - val_f1_score: 0.9166
# Epoch 22/35
# 222/222 [==============================] - 79s 357ms/step - loss: 0.1342 - accuracy: 0.9450 - f1_score: 0.9454 - val_loss: 0.1541 - val_accuracy: 0.9392 - val_f1_score: 0.9391
# Epoch 23/35
# 222/222 [==============================] - 81s 365ms/step - loss: 0.1276 - accuracy: 0.9480 - f1_score: 0.9485 - val_loss: 0.1714 - val_accuracy: 0.9358 - val_f1_score: 0.9351
# Epoch 24/35
# 222/222 [==============================] - 83s 373ms/step - loss: 0.1228 - accuracy: 0.9540 - f1_score: 0.9542 - val_loss: 0.1560 - val_accuracy: 0.9446 - val_f1_score: 0.9438
# Epoch 25/35
# 222/222 [==============================] - 90s 403ms/step - loss: 0.1225 - accuracy: 0.9534 - f1_score: 0.9536 - val_loss: 0.1435 - val_accuracy: 0.9468 - val_f1_score: 0.9464
# Epoch 26/35
# 222/222 [==============================] - 82s 369ms/step - loss: 0.1390 - accuracy: 0.9481 - f1_score: 0.9484 - val_loss: 0.1399 - val_accuracy: 0.9499 - val_f1_score: 0.9498
# Epoch 27/35
# 222/222 [==============================] - 91s 412ms/step - loss: 0.1170 - accuracy: 0.9586 - f1_score: 0.9588 - val_loss: 0.1378 - val_accuracy: 0.9505 - val_f1_score: 0.9505
# Epoch 28/35
# 222/222 [==============================] - 83s 376ms/step - loss: 0.1233 - accuracy: 0.9536 - f1_score: 0.9539 - val_loss: 0.1363 - val_accuracy: 0.9496 - val_f1_score: 0.9496
# Epoch 29/35
# 222/222 [==============================] - 91s 412ms/step - loss: 0.1284 - accuracy: 0.9492 - f1_score: 0.9495 - val_loss: 0.1340 - val_accuracy: 0.9513 - val_f1_score: 0.9513
# Epoch 30/35
# 222/222 [==============================] - 84s 379ms/step - loss: 0.1075 - accuracy: 0.9610 - f1_score: 0.9612 - val_loss: 0.1353 - val_accuracy: 0.9496 - val_f1_score: 0.9497
# Epoch 31/35
# 222/222 [==============================] - 93s 418ms/step - loss: 0.1071 - accuracy: 0.9600 - f1_score: 0.9602 - val_loss: 0.1331 - val_accuracy: 0.9513 - val_f1_score: 0.9514
# Epoch 32/35
# 222/222 [==============================] - 84s 377ms/step - loss: 0.1016 - accuracy: 0.9634 - f1_score: 0.9636 - val_loss: 0.1320 - val_accuracy: 0.9502 - val_f1_score: 0.9502
# Epoch 33/35
# 222/222 [==============================] - 91s 409ms/step - loss: 0.1118 - accuracy: 0.9612 - f1_score: 0.9614 - val_loss: 0.1316 - val_accuracy: 0.9519 - val_f1_score: 0.9519
# Epoch 34/35
# 222/222 [==============================] - 85s 383ms/step - loss: 0.1122 - accuracy: 0.9596 - f1_score: 0.9598 - val_loss: 0.1318 - val_accuracy: 0.9513 - val_f1_score: 0.9513
# Epoch 35/35
# 222/222 [==============================] - 91s 408ms/step - loss: 0.1136 - accuracy: 0.9557 - f1_score: 0.9558 - val_loss: 0.1316 - val_accuracy: 0.9519 - val_f1_score: 0.9519
# #### FOLD 2 Accuracy = 0.961
# #### FOLD 2 F1_score = 0.961
#
# FOLD: 3
# TRAIN: 7108 VALID: 3553
# Epoch 1/35
# 222/222 [==============================] - 99s 400ms/step - loss: 0.7487 - accuracy: 0.5997 - f1_score: 0.5948 - val_loss: 0.7333 - val_accuracy: 0.4571 - val_f1_score: 0.4296
# Epoch 2/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.6223 - accuracy: 0.6945 - f1_score: 0.7002 - val_loss: 1.0488 - val_accuracy: 0.3183 - val_f1_score: 0.1544
# Epoch 3/35
# 222/222 [==============================] - 79s 358ms/step - loss: 0.4787 - accuracy: 0.7991 - f1_score: 0.8020 - val_loss: 1.1282 - val_accuracy: 0.3194 - val_f1_score: 0.1568
# Epoch 4/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.3949 - accuracy: 0.8419 - f1_score: 0.8439 - val_loss: 1.2688 - val_accuracy: 0.3223 - val_f1_score: 0.1627
# Epoch 5/35
# 222/222 [==============================] - 89s 400ms/step - loss: 0.3263 - accuracy: 0.8646 - f1_score: 0.8664 - val_loss: 1.4932 - val_accuracy: 0.3231 - val_f1_score: 0.1654
# Epoch 6/35
# 222/222 [==============================] - 80s 361ms/step - loss: 0.2703 - accuracy: 0.8950 - f1_score: 0.8959 - val_loss: 1.3903 - val_accuracy: 0.3425 - val_f1_score: 0.2061
# Epoch 7/35
# 222/222 [==============================] - 89s 400ms/step - loss: 0.2571 - accuracy: 0.9030 - f1_score: 0.9038 - val_loss: 0.9922 - val_accuracy: 0.4666 - val_f1_score: 0.4288
# Epoch 8/35
# 222/222 [==============================] - 89s 402ms/step - loss: 0.2427 - accuracy: 0.9050 - f1_score: 0.9059 - val_loss: 0.8465 - val_accuracy: 0.5629 - val_f1_score: 0.5583
# Epoch 9/35
# 222/222 [==============================] - 80s 359ms/step - loss: 0.2278 - accuracy: 0.9082 - f1_score: 0.9090 - val_loss: 0.6630 - val_accuracy: 0.6772 - val_f1_score: 0.6862
# Epoch 10/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.2018 - accuracy: 0.9210 - f1_score: 0.9216 - val_loss: 0.4213 - val_accuracy: 0.8179 - val_f1_score: 0.8223
# Epoch 11/35
# 222/222 [==============================] - 89s 402ms/step - loss: 0.1910 - accuracy: 0.9206 - f1_score: 0.9215 - val_loss: 0.4962 - val_accuracy: 0.7661 - val_f1_score: 0.7741
# Epoch 12/35
# 222/222 [==============================] - 80s 360ms/step - loss: 0.1976 - accuracy: 0.9253 - f1_score: 0.9258 - val_loss: 0.3735 - val_accuracy: 0.8455 - val_f1_score: 0.8484
# Epoch 13/35
# 222/222 [==============================] - 90s 404ms/step - loss: 0.1858 - accuracy: 0.9304 - f1_score: 0.9308 - val_loss: 0.3148 - val_accuracy: 0.8778 - val_f1_score: 0.8780
# Epoch 14/35
# 222/222 [==============================] - 90s 404ms/step - loss: 0.1674 - accuracy: 0.9356 - f1_score: 0.9360 - val_loss: 0.2823 - val_accuracy: 0.8911 - val_f1_score: 0.8911
# Epoch 15/35
# 222/222 [==============================] - 79s 356ms/step - loss: 0.1625 - accuracy: 0.9397 - f1_score: 0.9399 - val_loss: 0.2676 - val_accuracy: 0.9119 - val_f1_score: 0.9091
# Epoch 16/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.1618 - accuracy: 0.9392 - f1_score: 0.9397 - val_loss: 0.2871 - val_accuracy: 0.9001 - val_f1_score: 0.8953
# Epoch 17/35
# 222/222 [==============================] - 89s 403ms/step - loss: 0.1541 - accuracy: 0.9372 - f1_score: 0.9377 - val_loss: 0.2897 - val_accuracy: 0.9001 - val_f1_score: 0.8947
# Epoch 18/35
# 222/222 [==============================] - 79s 357ms/step - loss: 0.1489 - accuracy: 0.9450 - f1_score: 0.9453 - val_loss: 0.2225 - val_accuracy: 0.9268 - val_f1_score: 0.9247
# Epoch 19/35
# 222/222 [==============================] - 94s 425ms/step - loss: 0.1447 - accuracy: 0.9423 - f1_score: 0.9428 - val_loss: 0.1804 - val_accuracy: 0.9355 - val_f1_score: 0.9349
# Epoch 20/35
# 222/222 [==============================] - 92s 413ms/step - loss: 0.1342 - accuracy: 0.9466 - f1_score: 0.9469 - val_loss: 0.1853 - val_accuracy: 0.9308 - val_f1_score: 0.9312
# Epoch 21/35
# 222/222 [==============================] - 79s 355ms/step - loss: 0.1298 - accuracy: 0.9488 - f1_score: 0.9491 - val_loss: 0.2005 - val_accuracy: 0.9263 - val_f1_score: 0.9270
# Epoch 22/35
# 222/222 [==============================] - 88s 396ms/step - loss: 0.1198 - accuracy: 0.9562 - f1_score: 0.9564 - val_loss: 0.2500 - val_accuracy: 0.9043 - val_f1_score: 0.9061
# Epoch 23/35
# 222/222 [==============================] - 89s 403ms/step - loss: 0.1288 - accuracy: 0.9520 - f1_score: 0.9523 - val_loss: 0.1971 - val_accuracy: 0.9243 - val_f1_score: 0.9251
# Epoch 24/35
# 222/222 [==============================] - 80s 358ms/step - loss: 0.1169 - accuracy: 0.9576 - f1_score: 0.9577 - val_loss: 0.1708 - val_accuracy: 0.9392 - val_f1_score: 0.9394
# Epoch 25/35
# 222/222 [==============================] - 87s 390ms/step - loss: 0.1119 - accuracy: 0.9533 - f1_score: 0.9536 - val_loss: 0.1603 - val_accuracy: 0.9426 - val_f1_score: 0.9426
# Epoch 26/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.1099 - accuracy: 0.9594 - f1_score: 0.9597 - val_loss: 0.2429 - val_accuracy: 0.9063 - val_f1_score: 0.9082
# Epoch 27/35
# 222/222 [==============================] - 80s 361ms/step - loss: 0.1014 - accuracy: 0.9621 - f1_score: 0.9622 - val_loss: 0.1531 - val_accuracy: 0.9471 - val_f1_score: 0.9471
# Epoch 28/35
# 222/222 [==============================] - 88s 399ms/step - loss: 0.1094 - accuracy: 0.9557 - f1_score: 0.9559 - val_loss: 0.1462 - val_accuracy: 0.9488 - val_f1_score: 0.9487
# Epoch 29/35
# 222/222 [==============================] - 89s 400ms/step - loss: 0.1196 - accuracy: 0.9552 - f1_score: 0.9554 - val_loss: 0.1493 - val_accuracy: 0.9476 - val_f1_score: 0.9476
# Epoch 30/35
# 222/222 [==============================] - 80s 362ms/step - loss: 0.1138 - accuracy: 0.9576 - f1_score: 0.9579 - val_loss: 0.1443 - val_accuracy: 0.9479 - val_f1_score: 0.9478
# Epoch 31/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.1044 - accuracy: 0.9599 - f1_score: 0.9602 - val_loss: 0.1442 - val_accuracy: 0.9496 - val_f1_score: 0.9496
# Epoch 32/35
# 222/222 [==============================] - 89s 403ms/step - loss: 0.1011 - accuracy: 0.9591 - f1_score: 0.9594 - val_loss: 0.1441 - val_accuracy: 0.9499 - val_f1_score: 0.9499
# Epoch 33/35
# 222/222 [==============================] - 79s 358ms/step - loss: 0.0943 - accuracy: 0.9631 - f1_score: 0.9634 - val_loss: 0.1466 - val_accuracy: 0.9479 - val_f1_score: 0.9480
# Epoch 34/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.1028 - accuracy: 0.9614 - f1_score: 0.9616 - val_loss: 0.1467 - val_accuracy: 0.9479 - val_f1_score: 0.9480
# Epoch 35/35
# 222/222 [==============================] - 89s 401ms/step - loss: 0.0934 - accuracy: 0.9664 - f1_score: 0.9665 - val_loss: 0.1468 - val_accuracy: 0.9482 - val_f1_score: 0.9483
# #### FOLD 3 Accuracy = 0.965
# #### FOLD 3 F1_score = 0.965
# ### Avg. Accuracy = 0.9623216986656189
#  ### Avg. Weighted F1 = 0.96245010693868

# %%
# Plot metrics:-
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)
# Out:
# FOLD: 1
# FOLD: 2
# FOLD: 3

# %%
TA=[]
TH=[]

TA.extend(ATL)
TH.extend(HTL)

print(len(TA))
print(len(TH))

# Create labels :-
Label_TA = [1]*len(TA)
Label_TH = [0]*len(TH)

# Converting to pandas dataframe for easier access:-
TA.extend(TH)
Label_TA.extend(Label_TH)
tdf = pd.DataFrame({'path':TA, 'label':Label_TA})
tdf = tdf.sample(frac=1).reset_index(drop=True)
TFILENAMES = tdf['path']
TLABELS = tdf['label']


print('Test Merged Data:-')
tdf
# Out:
# 1219
# 648
# Test Merged Data:-
#                                                    path  label
# 0     ../input/leukemia-classification//C-NMC_Leukem...      1
# 1     ../input/leukemia-classification//C-NMC_Leukem...      0
# 2     ../input/leukemia-classification//C-NMC_Leukem...      1
# 3     ../input/leukemia-classification//C-NMC_Leukem...      0
# 4     ../input/leukemia-classification//C-NMC_Leukem...      0
# ...                                                 ...    ...
# 1862  ../input/leukemia-classification//C-NMC_Leukem...      1
# 1863  ../input/leukemia-classification//C-NMC_Leukem...      1
# 1864  ../input/leukemia-classification//C-NMC_Leukem...      1
# 1865  ../input/leukemia-classification//C-NMC_Leukem...      1
# 1866  ../input/leukemia-classification//C-NMC_Leukem...      1
#
# [1867 rows x 2 columns]

# %%
test_dataset = get_dataset(TFILENAMES[:1867],TLABELS[:1867], ordered=True,augment=True)
test_iter = iter(train_dataset.unbatch().batch(20))

display_batch_of_images(next(test_iter))

# %%
accu = model.evaluate(test_dataset)
# Out:
# 59/59 [==============================] - 23s 367ms/step - loss: 0.4670 - accuracy: 0.8275 - f1_score: 0.8248

# %%
import PIL
from PIL import Image
im1 = Image.open(GCS_PATH + '/C-NMC_Leukemia/testing_data/C-NMC_test_final_phase_data/1105.bmp')
p1 = np.array(im1)
plt.imshow(p1)
p1 = np.expand_dims(p1, axis=0)
p1.shape
# Out:
# (1, 600, 600, 3)

# %%
preds = model.predict(p1)
prediction = np.argmax(preds)
pct = np.max(preds)
if prediction == 0:
    print('The Prediction of the sample is: It Is ALL')
else:
    print('Prediction is Hem')
print("Prediction Confidence Percentage is: ", pct*100)
plt.imshow(im1);
# Out:
# The Prediction of the sample is: It Is ALL
# Prediction Confidence Percentage is:  78.08951139450073
